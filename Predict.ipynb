# %%
import pandas as pd

data = pd.read_csv('./voyages.csv')
data.reset_index(drop=True)
# Out:
#       vessel           begin_date  ... begin_port_id  end_port_id
# 0          1  2019-01-01 17:54:00  ...         138.0        102.0
# 1          1  2019-01-17 19:26:00  ...         102.0        138.0
# 2          1  2019-02-14 19:55:00  ...         138.0         33.0
# 3          1  2019-03-02 04:54:00  ...          33.0        138.0
# 4          1  2019-03-17 00:59:00  ...         138.0         72.0
# ...      ...                  ...  ...           ...          ...
# 3143     176  2019-10-03 23:53:00  ...          64.0        117.0
# 3144     176  2019-10-23 05:55:00  ...         117.0         64.0
# 3145     176  2019-11-03 18:57:00  ...          64.0         56.0
# 3146     176  2019-11-21 02:29:00  ...          56.0        136.0
# 3147     176  2019-12-03 15:55:00  ...         136.0         64.0
#
# [3148 rows x 5 columns]

# %%
mode = data.groupby('begin_port_id')['end_port_id'].agg(lambda x:x.value_counts().index[0])
mode[138]
# Out:
# 134.0

# %%
vessel = data['vessel']
output = pd.DataFrame(columns=['vessel', 'begin_port_id', 'end_port_id', 'voyage'])
for i in vessel:
  row = data.loc[data['vessel'] == i].iloc[-1]
  v1 = mode[row['end_port_id']]
  v2 = mode[v1]
  v3 = mode[v2]
  o = [i, row['begin_port_id'], row['end_port_id'], [v1, v2, v3]]
  output.loc[i] = o
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
output.to_csv('predict.csv', index=False)
